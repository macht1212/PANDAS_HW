# %%
from numpy import random
import matplotlib.pyplot as plt

# %% [markdown]
# ### Распределение случайных значений из 10 000 вариантов

# %%
data_10k = []
for i in range(10000):
    num = []
    x = random.randint(0, 10, 3)
    for i, el in enumerate(x):
        a = str(x[i])
        num.append(a)
    data_10k.append(''.join(num))

# %%
plt.hist(data_10k)
# Out:
# (array([1166., 1086., 1102., 1016., 1070., 1011., 1023.,  892.,  872.,
#          762.]),
#  array([  0. ,  99.9, 199.8, 299.7, 399.6, 499.5, 599.4, 699.3, 799.2,
#         899.1, 999. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Распределение случайных значений из 1 000 000 вариантов

# %%
data_1M = []
for i in range(10000):
    num = []
    x = random.randint(0, 10, 3)
    for i, el in enumerate(x):
        a = str(x[i])
        num.append(a)
    data_1M.append(''.join(num))

# %%
plt.hist(data_1M)
# Out:
# (array([1104., 1142., 1088., 1052., 1018., 1011.,  982.,  969.,  883.,
#          751.]),
#  array([  0. ,  99.9, 199.8, 299.7, 399.6, 499.5, 599.4, 699.3, 799.2,
#         899.1, 999. ]),
#  <BarContainer object of 10 artists>)
